# %% [markdown]
# <a href="https://colab.research.google.com/github/IkerRivera/EPPL-area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/El_profe_circulo_Iker_Montoya_0105.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Iker Montoya NL Fecha 25/mar/2026
# ---
# # calcular area y perimetro de un circulo
# ---
# ![Logo de Markdown](https://github.com/IkerRivera/EPPL-area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/circuloareaperimetro.png?raw=true)
#
# ---
# ## formula para calcular Area
# $=A=\pi*r^2$
#
# ---
# ### formula para calcular perimetro
# $P=2*\pi*r$
#
#
# ---
# ### datos de entrada
# $r$ ?
#
# ---
# ### diagrama de flujo lucidchat
# ![Logo de Markdown](https://github.com/IkerRivera/EPPL-area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/DF%20Area%20Area%20perimetro%20circulo.png?raw=true)

# %%
# calcula area perimetro del circulo
# variable p, a, r
#formula A= pi*r^ y P = 2 * pi * r
# Capturar el valor de r
import math
print("Calcular Area y Perimetro de un Circulo")
r = float(input("Ingrese el radio del circulo: "))
A =math.pi* r**2
P = 2 * math.pi * r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
print("Iker Montoya n = 38")56
# Out:
# Calcular Area y Perimetro de un Circulo
# Ingrese el radio del circulo: 65
# El area del circulo es:  13273.228961416877
# El perimetro del circulo es:  408.4070449666731
# Iker Montoya n = 38

# %% [markdown]
# # relacion entr codigo y DF y telegram
# ![Logo de Markdown]![Logo de Markdown](https://github.com/IkerRivera/EPPL-area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/codigo%20DF.png?raw=true)
