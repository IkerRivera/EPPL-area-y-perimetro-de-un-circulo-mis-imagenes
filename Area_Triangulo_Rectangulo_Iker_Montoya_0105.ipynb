# %% [markdown]
# <a href="https://colab.research.google.com/github/IkerRivera/EPPL-area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/Area_Triangulo_Rectangulo_Iker_Montoya_0105.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###  Iker Montoya NL Fecha 25/mar/2026
# ---
# # calcular area de un traingulo
# ---
# ![Logo de Markdown](https://www.problemasyecuaciones.com/geometria2D/area/triangulo/Tg5.png)
# ---
# ## formula para calcular Area
#
# $$A = \frac{b \cdot h}{2}$$
#
# ---
# #datos de entrada
# $A$ ?
#
# ---
# ### diagrama de flujo lucidchat
# ![Logo de Markdown](https://github.com/IkerRivera/EPPL-area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/Diagrama%20area%20triangulo.png?raw=true)

# %%
# Capturar el valor de b y h
# calcula area del triangulo:
# variable b, h, A
# formula A = (b * h) / 2
print("Calcular Area de un Triangulo")

b = float(input("Ingrese la base del triangulo: "))
h = float(input("Ingrese la altura del triangulo: "))

# Cálculo del área
A = (b * h) / 2

print("El area del triangulo es: ", A)
print("Iker Montoya n = 38")
# Out:
# Calcular Area de un Triangulo
# Ingrese la base del triangulo: 34
# Ingrese la altura del triangulo: 34
# El area del triangulo es:  578.0
# Iker Montoya n = 38

# %% [markdown]
# # relacion entre codigo DF y Telegram
# ![Logo de Markdown](https://github.com/IkerRivera/EPPL-area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/diagrama%20y%20codigo.PNG?raw=true)
